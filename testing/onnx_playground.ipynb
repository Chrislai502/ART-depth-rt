# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class MyModel(nn.Module):

    def __init__(self):
        super(MyModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
torch_model = MyModel()
torch_input = torch.randn(1, 1, 32, 32)
onnx_program = torch.onnx.dynamo_export(torch_model, torch_input)
# Out:
# /home/art-chris/anaconda3/envs/artdepth/lib/python3.11/site-packages/onnxscript/converter.py:820: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# /home/art-chris/anaconda3/envs/artdepth/lib/python3.11/site-packages/onnxscript/converter.py:820: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# /home/art-chris/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/_exporter_legacy.py:116: UserWarning: torch.onnx.dynamo_export only implements opset version 18 for now. If you need to use a different opset version, please register them with register_custom_op.
#   warnings.warn(
# /home/art-chris/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1230: UserWarning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (Triggered internally at ../torch/csrc/PyInterpreter.cpp:260.)
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/_exporter_legacy.py:1222, in dynamo_export(model, export_options, *model_args, **model_kwargs)
#    1216     with _dynamo_config.patch(do_not_emit_runtime_asserts=True):
#    1217         return Exporter(
#    1218             options=resolved_export_options,
#    1219             model=model,
#    1220             model_args=model_args,
#    1221             model_kwargs=model_kwargs,
# -> 1222         ).export()
#    1223 except Exception as e:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/_exporter_legacy.py:976, in Exporter.export(self)
#     973 with self.options.diagnostic_context, decomposition_skip.enable_decomposition_skips(
#     974     self.options
#     975 ), torch._dynamo.config.patch(dataclasses.asdict(DEFAULT_EXPORT_DYNAMO_CONFIG)):
# --> 976     graph_module = self.options.fx_tracer.generate_fx(
#     977         self.options, self.model, self.model_args, self.model_kwargs
#     978     )
#     979     # TODO: Defer `import onnxscript` out of `import torch` path
#     980     # https://github.com/pytorch/pytorch/issues/103764
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/fx/dynamo_graph_extractor.py:217, in DynamoExport.generate_fx(self, options, model, model_args, model_kwargs)
#     213 updated_model_args = self.input_adapter.apply(
#     214     *model_args, model=model, **model_kwargs
#     215 )
# --> 217 return self.pre_export_passes(options, model, graph_module, updated_model_args)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/fx/dynamo_graph_extractor.py:226, in DynamoExport.pre_export_passes(self, options, original_model, fx_module, fx_module_args)
#     219 def pre_export_passes(
#     220     self,
#     221     options: _exporter_legacy.ResolvedExportOptions,
#    (...)
#     224     fx_module_args: Sequence[Any],
#     225 ):
# --> 226     return _exporter_legacy.common_pre_export_passes(
#     227         options, original_model, fx_module, fx_module_args
#     228     )
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/_exporter_legacy.py:1248, in common_pre_export_passes(options, original_model, fx_module, fx_module_args)
#    1247 # Apply decomposition table to the input graph.
# -> 1248 module = passes.Decompose(
#    1249     diagnostic_context,
#    1250     fx_module,
#    1251     options.decomposition_table,
#    1252     enable_dynamic_axes=options.dynamic_shapes,
#    1253     allow_fake_constant=options.fake_context is not None,
#    1254 ).run(*fx_module_args)
#    1256 # ONNX does not support views and mutations.
#    1257 # Functionalize to get a semantically equivalent graph without mutations.
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/decorator.py:146, in diagnose_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     145 finally:
# --> 146     ctx.log_and_raise_if_error(diag)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/context.py:355, in DiagnosticContext.log_and_raise_if_error(self, diagnostic)
#     354 if diagnostic.source_exception is not None:
# --> 355     raise diagnostic.source_exception
#     356 raise RuntimeErrorWithDiagnostic(diagnostic)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/decorator.py:130, in diagnose_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     129 try:
# --> 130     return_values = fn(*args, **kwargs)
#     131     with diag.log_section(logging.INFO, "Return values"):
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/fx/_pass.py:275, in Transform.run(self, *args, **kwargs)
#     273     old_tabular = ""
# --> 275 module = self._run(*args, **kwargs)
#     277 # Gather graph information after transform.
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/fx/passes/decomp.py:70, in Decompose._run(self, *args, **kwargs)
#      69 with fake_tensor.unset_fake_temporarily(), python_dispatch.enable_python_dispatcher(), fake_mode:
# ---> 70     decomposed_module = proxy_tensor.make_fx(
#      71         module,
#      72         decomposition_table=self.decomposition_table,
#      73         tracing_mode=tracing_mode,
#      74         _allow_non_fake_inputs=True,
#      75         _allow_fake_constant=bool(self.allow_fake_constant),
#      76     )(*maybe_fake_args)
#      78 # Rename placeholder targets to match the original module's signature since
#      79 # We don't want to map forward(x, y, z) to forward(arg0, arg1, arg2).
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:2110, in make_fx.<locals>.wrapped(*args)
#    2108 @functools.wraps(f)
#    2109 def wrapped(*args: object) -> GraphModule:
# -> 2110     return make_fx_tracer.trace(f, *args)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:2048, in _MakefxTracer.trace(self, f, *args)
#    2047 with self._init_modes_from_inputs(f, args):
# -> 2048     return self._trace_inner(f, *args)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:2034, in _MakefxTracer._trace_inner(self, f, *args)
#    2033     assert self.fx_tracer is not None
# -> 2034     t = dispatch_trace(
#    2035         wrap_key(func, args, self.fx_tracer, self.pre_dispatch),
#    2036         tracer=self.fx_tracer,
#    2037         concrete_args=tuple(phs),
#    2038     )
#    2040 # TODO: kind of a bad way to do it, should maybe figure out a better way
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_compile.py:32, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      30     fn.__dynamo_disable = disable_fn
# ---> 32 return disable_fn(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     631 try:
# --> 632     return fn(*args, **kwargs)
#     633 finally:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1127, in dispatch_trace(root, tracer, concrete_args)
#    1121 @torch._disable_dynamo
#    1122 def dispatch_trace(
#    1123     root: Union[Module, Callable],
#    1124     tracer: Tracer,
#    1125     concrete_args: Optional[Tuple[Any, ...]] = None,
#    1126 ) -> GraphModule:
# -> 1127     graph = tracer.trace(root, concrete_args)  # type: ignore[arg-type]
#    1129     # NB: be careful not to DCE .item() calls
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     631 try:
# --> 632     return fn(*args, **kwargs)
#     633 finally:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/_symbolic_trace.py:823, in Tracer.trace(self, root, concrete_args)
#     817         _autowrap_check(
#     818             patcher, module.__dict__, self._autowrap_function_ids
#     819         )
#     820     self.create_node(
#     821         "output",
#     822         "output",
# --> 823         (self.create_arg(fn(*args)),),
#     824         {},
#     825         type_expr=fn.__annotations__.get("return", None),
#     826     )
#     828 self.submodule_paths = None
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1182, in wrap_key.<locals>.wrapped(*proxies, **_unused)
#    1180     return get_proxy_slot(t, tracer, t, lambda x: x.proxy)
# -> 1182 out = f(*tensors)
#    1183 out = pytree.tree_map_only(Tensor, get_tensor_proxy_slot, out)
#
# File <string>:1, in <lambda>(arg0)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/fx/passes/_utils.py:28, in wrap_graph_module_for_node_meta_preservation.<locals>.wrapped(*args)
#      27 with fx_traceback.preserve_node_meta():
# ---> 28     return torch.fx.Interpreter(graph_module).run(*args)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/interpreter.py:146, in Interpreter.run(self, initial_env, enable_io_processing, *args)
#     145 try:
# --> 146     self.env[node] = self.run_node(node)
#     147 except Exception as e:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/interpreter.py:203, in Interpreter.run_node(self, n)
#     202 assert isinstance(kwargs, dict)
# --> 203 return getattr(self, n.op)(n.target, args, kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/interpreter.py:320, in Interpreter.call_module(self, target, args, kwargs)
#     318 submod = self.fetch_attr(target)
# --> 320 return submod(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/_symbolic_trace.py:801, in Tracer.trace.<locals>.module_call_wrapper(mod, *args, **kwargs)
#     796 _autowrap_check(
#     797     patcher,  # type: ignore[has-type]
#     798     getattr(getattr(mod, "forward", mod), "__globals__", {}),
#     799     self._autowrap_function_ids,
#     800 )
# --> 801 return self.call_module(mod, forward, args, kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1039, in PythonKeyTracer.call_module(self, m, forward, args, kwargs)
#    1032 def call_module(
#    1033     self,
#    1034     m: Module,
#    (...)
#    1037     kwargs: Dict[str, Any],
#    1038 ) -> Any:
# -> 1039     return forward(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/_symbolic_trace.py:794, in Tracer.trace.<locals>.module_call_wrapper.<locals>.forward(*args, **kwargs)
#     793 def forward(*args, **kwargs):
# --> 794     return _orig_module_call(mod, *args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1230, in TorchFunctionMetadataMode.__torch_function__(self, func, types, args, kwargs)
#    1229 self.tracer.torch_fn_counts[func] = self.tracer.torch_fn_counts.get(func, 0) + 1
# -> 1230 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/utils/_stats.py:21, in count.<locals>.wrapper(*args, **kwargs)
#      20 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 21 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1308, in ProxyTorchDispatchMode.__torch_dispatch__(self, func, types, args, kwargs)
#    1306     return func(*args, **kwargs)
# -> 1308 return proxy_call(self, func, self.pre_dispatch, args, kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:906, in proxy_call(proxy_mode, func, pre_dispatch, args, kwargs)
#     905 with _enable_thunkify(proxy_mode.tracer):
# --> 906     out = func(*args, **kwargs)
#     908 # In some circumstances, we will be tracing in a situation where a tensor
#     909 # is *statically* known to be a constant (currently, this only happens if
#     910 # you run torch.tensor; deterministic factory functions like torch.arange
#    (...)
#     927 # propagating const-ness.  Similarly, we don't require the constant to
#     928 # live on CPU, but we could.
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_ops.py:716, in OpOverload.__call__(self, *args, **kwargs)
#     715 def __call__(self, /, *args, **kwargs):
# --> 716     return self._op(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/utils/_stats.py:21, in count.<locals>.wrapper(*args, **kwargs)
#      20 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 21 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_tensor.py:1238, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#    1237 try:
# -> 1238     return self.dispatch(func, types, args, kwargs)
#    1239 except TypeError:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_tensor.py:1692, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1691 if self.cache_enabled:
# -> 1692     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1693 else:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_tensor.py:1348, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1347 if output is _UNASSIGNED:
# -> 1348     output = self._dispatch_impl(func, types, args, kwargs)
#    1350 return output
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_tensor.py:1983, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    1982 if run_impl_check(func):
# -> 1983     op_impl_out = op_impl(self, func, *args, **kwargs)
#    1984     if op_impl_out is not NotImplemented:
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_impls.py:147, in dispatch_to_op_implementations_dict(fake_mode, func, *args, **kwargs)
#     145 @register_op_impl(op_implementations_dict.__contains__)
#     146 def dispatch_to_op_implementations_dict(fake_mode, func, *args, **kwargs):
# --> 147     return op_implementations_dict[func](fake_mode, func, *args, **kwargs)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/_subclasses/fake_impls.py:683, in conv(fake_mode, func, *args, **kwargs)
#     682 if func is aten.convolution.default:
# --> 683     conv_backend = torch._C._select_conv_backend(**kwargs)
#     684 else:
#
# RuntimeError: expected stride to be a single integer value or a list of -1 values to match the convolution dimensions, but got stride=[1, 1]
#
# While executing %l__self___conv1 : [num_users=1] = call_module[target=L__self___conv1](args = (%l_x_,), kwargs = {})
# Original traceback:
#   File "/tmp/ipykernel_32398/1419832373.py", line 17, in forward
#     x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
#
#
# The above exception was the direct cause of the following exception:
#
# OnnxExporterError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 torch_model = MyModel()
#       2 torch_input = torch.randn(1, 1, 32, 32)
# ----> 3 onnx_program = torch.onnx.dynamo_export(torch_model, torch_input)
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/__init__.py:517, in dynamo_export(model, export_options, *model_args, **model_kwargs)
#     514 else:
#     515     from torch.onnx._internal._exporter_legacy import dynamo_export
# --> 517     return dynamo_export(
#     518         model, *model_args, export_options=export_options, **model_kwargs
#     519     )
#
# File ~/anaconda3/envs/artdepth/lib/python3.11/site-packages/torch/onnx/_internal/_exporter_legacy.py:1233, in dynamo_export(model, export_options, *model_args, **model_kwargs)
#    1225 resolved_export_options.diagnostic_context.dump(sarif_report_path)
#    1226 message = (
#    1227     f"Failed to export the model to ONNX. Generating SARIF report at '{sarif_report_path}'. "
#    1228     "SARIF is a standard format for the output of static analysis tools. "
#    (...)
#    1231     f"Please report a bug on PyTorch Github: {_PYTORCH_GITHUB_ISSUES_URL}"
#    1232 )
# -> 1233 raise errors.OnnxExporterError(message) from e
#
# OnnxExporterError: Failed to export the model to ONNX. Generating SARIF report at 'report_dynamo_export.sarif'. SARIF is a standard format for the output of static analysis tools. SARIF logs can be loaded in VS Code SARIF viewer extension, or SARIF web viewer (https://microsoft.github.io/sarif-web-component/). Please report a bug on PyTorch Github: https://github.com/pytorch/pytorch/issues

# %%
onnx_program.save("my_image_classifier.onnx")

# %%
import onnx
onnx_model = onnx.load("my_image_classifier.onnx")
onnx.checker.check_model(onnx_model)
